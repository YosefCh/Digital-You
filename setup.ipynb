# %%
from postgres import initiate_database
initiate_database()
# Out:
# ✅ Statement executed: -- Dimension tables
# -- Food dimension table.
#
# CRE...
# ✅ Statement executed: CREATE TABLE IF NOT EXISTS exercise (
#   exercise_i...
# ✅ Statement executed: CREATE TABLE IF NOT EXISTS activity (
#   activity_i...
# ✅ Statement executed: -- Fact tables
# CREATE TABLE IF NOT EXISTS food_log...
# ✅ Statement executed: CREATE INDEX IF NOT EXISTS food_log_log_date_idx O...
# ✅ Statement executed: CREATE INDEX IF NOT EXISTS food_log_food_id_idx ON...
# ✅ Statement executed: -- Only enforce uniqueness for regular foods (comb...
# ✅ Statement executed: -- Required for EXCLUDE constraints that use "=" o...
# ✅ Statement executed: CREATE TABLE IF NOT EXISTS exercise_log (
#   exerci...
# ✅ Statement executed: CREATE INDEX IF NOT EXISTS exercise_log_log_date_i...
# ✅ Statement executed: CREATE INDEX IF NOT EXISTS exercise_log_exercise_i...
# ✅ Statement executed: -- ...existing code...
# CREATE TABLE IF NOT EXISTS ...
# ...
