# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # SEE CHATGPT IN EDGE FOR BETTER IDEA FOR RELOADING MODULES

# %%
from IPython.display import HTML, display
import postgres
from datetime import datetime


if postgres.DB_NAME == postgres.LIVE_DB_NAME:
    banner_color = 'green'
    banner_text = '⚠️ LIVE DATABASE ACTIVE'
else:
    banner_color = "#A7510B"
    banner_text = f'🧪 DEV DATABASE ACTIVE: {postgres.DB_NAME}'
    
display(HTML(f'''
<div style="background:{banner_color}; color:white; padding:12px 16px; border-radius:10px; font-weight:bold; font-size:16px; border:2px solid rgba(255,255,255,0.35); margin-bottom:14px;">
{banner_text}
<p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;As of &nbsp;{datetime.now().strftime("%Y-%m-%d")} | {datetime.now().strftime("%I:%M %p").lstrip("0")}</p>
</div>

'''))
# Out:
# <div style="background:green; color:white; padding:12px 16px; border-radius:10px; font-weight:bold; font-size:16px; border:2px solid rgba(255,255,255,0.35); margin-bottom:14px;">
# ⚠️ LIVE DATABASE ACTIVE
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;As of &nbsp;2026-09-08 | 11:54 PM</p>
# </div>

# %%
from IPython.display import HTML, display
import postgres

dev_html = """
<div style="
    background:#A7510B;
    color:white;
    padding:10px 16px;
    border-radius:8px;
    font-weight:bold;
    font-size:16px;
    text-align:center;
    border:2px solid #D9822B;
">
    🧪 DEV DATABASE ACTIVE
</div>
"""

live_html = """
<div style="
    background:green;
    color:white;
    padding:10px 16px;
    border-radius:8px;
    font-weight:bold;
    font-size:16px;
    text-align:center;
    border:2px solid #90EE90;
">
    ⚠️ LIVE DATABASE ACTIVE
</div>
"""

# %%
from ui_functions import UIFunctions
ui = UIFunctions()

# %%
if postgres.DB_NAME.startswith("DEV"):
    display(HTML(dev_html))
else:
    display(HTML(live_html))
ui.ui_insert_food()
# Out:
# <div style="
#     background:green;
#     color:white;
#     padding:10px 16px;
#     border-radius:8px;
#     font-weight:bold;
#     font-size:16px;
#     text-align:center;
#     border:2px solid #90EE90;
# ">
#     ⚠️ LIVE DATABASE ACTIVE
# </div>
# VBox(children=(Checkbox(value=False, description='Override date'), DatePicker(value=datetime.date(2026, 9, 8),…
# Output()

# %%
if postgres.DB_NAME.startswith("DEV"):
    display(HTML(dev_html))
else:
    display(HTML(live_html))
ui.ui_insert_exercise()
# Out:
# LIVE_wellness_tracker
# Checkbox(value=False, description='Override date')
# DatePicker(value=datetime.date(2026, 9, 8), description='Log Date:', layout=Layout(display='none'), step=1)
# Dropdown(description='Type:', options=('Cardio', 'Mobility', 'Physical Therapy', 'Strength'), value='Cardio')
# Dropdown(description='Exercise:', options=('Basketball', 'Biking', 'Jogging', 'Jump Rope', 'Rowing', 'Soccer',…
# BoundedIntText(value=5, description='Minutes:', max=1440, min=1)
# Textarea(value='', description='Notes:', layout=Layout(height='80px', width='80%'))
# Button(description='Submit', style=ButtonStyle())
# Output()

# %%
if postgres.DB_NAME.startswith("DEV"):
    display(HTML(dev_html))
else:
    display(HTML(live_html))
ui.ui_insert_activity()

# %%
if postgres.DB_NAME.startswith("DEV"):
    display(HTML(dev_html))
else:
    display(HTML(live_html))
ui.ui_insert_stress()

# %% [markdown]
# <div style="background:rgb(1, 16, 40);padding:10px;border-radius:5px;margin-top:20px;width:95%">
#
# <details><summary style="color:white;font-size:18px;font-weight:bold;">Sleep Data Notes</summary>
#
#
#
#
# ### How to compute sleep in SQL (later)
# - **Time in bed (minutes)**:
#   - `EXTRACT(EPOCH FROM (wake_time - bedtime))/60`
# - **Estimated total minutes asleep**:
#   - `time_in_bed_minutes - COALESCE(awake_gap_minutes, 0)`
# - **Uninterrupted flag (derived)**:
#   - `awake_gap_minutes IS NULL OR awake_gap_minutes = 0`
#
# ### Late night followed by an early night (edge case)
# If `bedtime` is after midnight on day X, it will be recorded as the actual date, despite being inconsistent with the user's perception of "date". For example, if a user goes to bed after Sunday Jan 1st at 1am on Jan 2nd, it will be recorded as `bedtime = '2024-01-02 01:00:00'`. If on Monday they go to bed at 11pm, it will be recorded as `bedtime = '2024-01-02 23:00:00'`. This can lead to confusion when analyzing sleep patterns by date, since the Jan 2nd sleep will be associated with Jan 2nd instead of Jan 1st.
#
# This must be addressed either in the insert or in the select when analyzing sleep. We also must take into cosideration that we still want a constraint to catch duplicate entries. One solution is to have a separate `sleep_date` column that represents the user's perception of the date for that sleep session, and enforce uniqueness on `(user_id, sleep_date)`. The `bedtime` and `wake_time` can still be stored as timestamps without modification.
#
# </details>

# %%
if postgres.DB_NAME.startswith("DEV"):
    display(HTML(dev_html))
else:
    display(HTML(live_html))
ui.insert_sleep_water_weather()

# %%
if postgres.DB_NAME.startswith("DEV"):
    display(HTML(dev_html))
else:
    display(HTML(live_html))
ui.ui_insert_weight_waist()
